# %% [markdown]
# ### https://github.com/lucasharada/Curso_Python

# %% [markdown]
# ### Matplotlib: Python plotting

# %% [markdown]
# A GOOD TUTORIAL - https://www.labri.fr/perso/nrougier/teaching/matplotlib/

# %% [markdown]
# ## Installing

# %% [markdown]
# Choose one of the following commands:
#
# `conda install matplotlib`
#
# `pip install matplotlib`

# %%
import matplotlib.pyplot as plt

# %%
# To allow visualizing plots on Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ### Example 01 - Plotting

# %%
import numpy as np

x1 = np.linspace(-10,10,100)
y1 = x1 ** 3

# %%
plt.plot(x1, y1)
plt.show()

# %%
plt.plot(x1, y1, 'g--')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title("Example 01")
plt.show()

# %% [markdown]
# #### Assignment 01
#
# Implement the plotter of $sen(x)$ for $[0, 2\pi]$

# %%
x = np.linspace(0, 2 * np.pi, 360)
y = np.sin(x)
plt.plot(x, y, 'r')
plt.title("Seno")
plt.show()

# %% [markdown]
# ### Example 02 - Subplots

# %%
x2 = np.linspace(0, 2 * np.pi, 100)
y21 = np.sin(x2)
y22 = np.cos(x2)
plt.subplot(1, 3, 1) # Row 1 Column 2 Plot 1
plt.plot(x2, y21, 'go')
plt.subplot(1, 3, 2) # Row 1 Column 2 Plot 2
plt.plot(x2, y22, 'b*')
plt.subplot(1, 3, 3) # Row 1 Column 2 Plot 1
plt.plot(x2, y21)
plt.show()

# %% [markdown]
# ### Example 3 - Object Oriented Programming

# %%
x3 = np.linspace(-2, 2, 100)
y3 = x3 ** 4
figure3 = plt.figure()
axes = figure3.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x3, y3)
axes.set_xlabel('X3')
axes.set_ylabel('Y3')
axes.set_title("Example 03")
plt.show()

# %% [markdown]
# #### Assignment 02
#
# Implement the plotter of $cos(x)$ for $[0, 2\pi]$ using OOP

# %%
xCos = np.linspace(0, 2 * np.pi, 360)
yCos = np.cos(xCos)
figureCos = plt.figure()
axes = figureCos.add_axes([0.1, 0.1, 1, 1])
axes.plot(xCos,yCos)
axes.set_xlabel("xCos")
axes.set_ylabel("yCos")
axes.set_title("Cosseno")
plt.show()

# %% [markdown]
# ### Example 04 - Subplots using OOP

# %%
figure4 = plt.figure()
# add_axes([left, bottom, width, height])
axes41 = figure4.add_axes([0.1, 0.1, 0.8, 0.8])
axes42 = figure4.add_axes([0.2, 0.4, 0.4, 0.4])
x4 = np.linspace(0, 2 * np.pi, 100)
y4 = np.sin(x4)
axes41.plot(x4, y4)
axes42.plot(y4, x4)
plt.show()

# %% [markdown]
# ### Example 05 - Adjusting subplots
#
# Trying to create multiple subplots and draw into plots.

# %%
figure5, axes5 = plt.subplots(2, 2)
plt.tight_layout()
plt.show()

# %%
x5 = np.linspace(0, 5, 10)
y5 = x5 ** 2
for ax in axes5.flat:
    ax.plot(x5, y5)
figure5

# %%
axes5
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111a73390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111a3b860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111a20e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111f404e0>]],
#       dtype=object)

# %%
axes5[0,1].plot(x5, 2 * y5)
figure5

# %% [markdown]
# #### Assignment 03
#
# (a) Implement a subplot 1x2 containing $sin(x)$ and $cos(x)$ for $[0, 2\pi]$
#
# (b) Implement a subplot 2x2 containing $1/x^2$, $1/x$, $x$ and $x^2$ for $[-3, 3]$

# %%
#mine
figure, axes = plt.subplots(1, 2)
plt.tight_layout()
x = np.linspace(0, 2 * np.pi, 360)
y = [np.sin(x), np.cos(x)]
axes[0].set_title("Cosseno")
axes[1].set_title("Seno")
axes[0].plot(x, ySen)
axes[1].plot(x, yCos)
plt.show()

# %%
#example 
x = np.linspace(0, 2 * np.pi, 360)
y1 = np.sin(x)
y2 = np.cos(x)
figure, axes = plt.subplots(1, 2)
axes[0].plot(x, y1)
axes[1].plot(x, y2)
plt.tight_layout()
plt.show()

# %%
x = np.linspace(-3, 3, 100)
y1 = 1 / (x ** 2)
y2 = 1 / x
y3 = x
y4 = x ** 2
figure, axes = plt.subplots(2, 2)
axes[0, 0].plot(x, y1)
axes[0, 1].plot(x, y2)
axes[1, 0].plot(x, y3)
axes[1, 1].plot(x, y4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Example 06 - Size, DPI and export

# %%
figure61 = plt.figure(figsize = (2, 2))
axes61 = figure61.add_axes([0.1, 0.1, 1, 1])
x61 = np.linspace(0, 1, 10)
y61 = x61 ** 2
axes61.plot(x61, y61)

# %%
figure62, axes62 = plt.subplots(1, 2, figsize = (8, 2))
x62 = np.linspace(0, 2 * np.pi, 100)
y62 = np.sin(x62)
y63 = np.cos(x62)
axes62[0].plot(x62, y62)
axes62[1].plot(x62, y63)
plt.tight_layout()

# %%
figure62.savefig("figure62.jpg", dpi=100)

# %% [markdown]
# ### Example 07 - Legends

# %%
figure7 = plt.figure()
axes7 = figure7.add_axes([0.1, 0.1, 0.8, 0.8])
x7 = np.linspace(-5, 5, 100)
y71 = x7 ** 2
y72 = 2 * x7
axes7.plot(x7, y71, 'y', label='Yellow line')
axes7.plot(x7, y72, 'r', label='Red line')
# axes7.legend(loc = 5)
# Possible loc values
# 0 => 'best' (only implemented for axes legends);
# 1 => 'upper right';
# 2 => 'upper left';
# 3 => 'lower left';
# 4 => 'lower right';
# 5 => 'center right';
# 6 => 'center left';
# 7 => 'center right';
# 8 => 'lower center';
# 9 => 'upper center';
# 10 => 'center';
# tuple => (left, bottom)

axes7.legend(loc = (0.05, 0.05))

# %% [markdown]
# #### Assignment 04
#
# Consider $PL=20\times log_{10}{(d)}+20\times log_{10}{(f)} +32.45 dB$, where $d$ is the distance in $km$ and $f$ is the frequency in $MHz$.
#
# Implement plotters with legends for frequencies equal to 1.1 $MHz$ and 100 $MHz$ and distance between 0 and 5 $km$.

# %%
x = np.linspace(0.1, 5, 100)
pl1 = 20 * (np.log10(x) + np.log(1.1)) + 32.45
pl2 = 20 * (np.log10(x) + np.log(100)) + 32.45
figure = plt.figure()
axes = figure.add_axes([0.1, 0.1, 1, 1])
axes.plot(x, pl1, label="1.1MHz")
axes.plot(x, pl2, label="100MHz")
plt.legend(loc=0)
plt.show()

# %%
x = np.linspace(0.1, 5, 100)
y1 = 20 * np.log10(x) + 20 * np.log10(1.1) + 32.45
y2 = 20 * np.log10(x) + 20 * np.log10(100) + 32.45
figure = plt.figure()
axes = figure.add_axes([0.1, 0.1, 1, 1])
axes.plot(x, y1, label = '1.1 MHz')
axes.plot(x, y2, label = '100 MHz')
plt.legend(loc = 0)
plt.show()

# %% [markdown]
# ### Example 08 - Customization

# %%
x8 = np.linspace(0, 10, 20)
y81 = x8 * 5
y82 = x8 ** 10

figure8 = plt.figure()
axes8 = figure8.add_axes([0.1, 0.1, 0.8, 0.8])
axes8.plot(x8, y81, color='red', linewidth=3, alpha=1, linestyle='-')
axes8.plot(x8, y82, color='#000000', lw=3, alpha=0.7, ls='-.', marker='*', markersize=10)
axes8.set_xlim([2, 14])
axes8.set_ylim([20, 80])
# linestyle options => ["-", "--","-.", ":"]
# Out:
# (20, 80)
